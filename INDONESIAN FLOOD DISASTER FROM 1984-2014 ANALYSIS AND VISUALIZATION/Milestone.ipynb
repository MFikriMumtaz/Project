# %%
import pandas as pd

# %%
df = pd.read_csv('Flood_Data_Modified.csv',sep=';')
df
# Out:
#       Register_ID      Country Validation       Began       Ended  \
# 0          4214.0     Columbia       News  2014-11-01  2014-12-14
# 1          4213.0          USA       News  2014-12-11  2014-12-14
# 2          4212.0       Brazil       News  2014-12-10  2014-12-14
# 3          4211.0     Bulgaria       News  2014-12-04  2014-12-14
# 4          4210.0    Palestine       News  2014-11-26  2014-12-05
# ...           ...          ...        ...         ...         ...
# 4209          5.0   Mozambique       News  1985-02-09  1985-02-11
# 4210          4.0    Indonesia       News  1985-02-04  1985-02-18
# 4211          3.0  Phillipines       News  1985-01-20  1985-01-21
# 4212          2.0       Brazil       News  1985-01-15  1985-02-02
# 4213          1.0      Algeria       News  1985-01-01  1985-01-05
#
#       Duration in Days   Dead  Displaced        Main cause  Severity  ...  \
# 0                 44.0   44.0        0.0        Heavy Rain       1.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4214 entries, 0 to 4213
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Register_ID              4213 non-null   float64
#  1   Country                  4207 non-null   object
#  2   Validation               4213 non-null   object
#  3   Began                    4207 non-null   object
#  4   Ended                    4207 non-null   object
#  5   Duration in Days         4207 non-null   float64
#  6   Dead                     4207 non-null   float64
#  7   Displaced                4207 non-null   float64
#  8   Main cause               4207 non-null   object
#  9   Severity                 4207 non-null   float64
#  10  Affected sq km           4207 non-null   float64
#  11  Magnitude                4208 non-null   float64
#  12  Longitude of Centroid X  4207 non-null   float64
#  13  Latitude of Centroid Y   4207 non-null   float64
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       Register_ID      Country Validation       Began       Ended  \
# 0          4214.0     Columbia       News  2014-11-01  2014-12-14
# 1          4213.0          USA       News  2014-12-11  2014-12-14
# 2          4212.0       Brazil       News  2014-12-10  2014-12-14
# 3          4211.0     Bulgaria       News  2014-12-04  2014-12-14
# 4          4210.0    Palestine       News  2014-11-26  2014-12-05
# ...           ...          ...        ...         ...         ...
# 4209          5.0   Mozambique       News  1985-02-09  1985-02-11
# 4210          4.0    Indonesia       News  1985-02-04  1985-02-18
# 4211          3.0  Phillipines       News  1985-01-20  1985-01-21
# 4212          2.0       Brazil       News  1985-01-15  1985-02-02
# 4213          1.0      Algeria       News  1985-01-01  1985-01-05
#
#       Duration in Days   Dead  Displaced        Main cause  Severity  ...  \
# 0                 44.0   44.0        0.0        Heavy Rain       1.0  ...
# ...

# %%
indonesia = df[df["Country"] == 'Indonesia']
indonesia.head(5)
# Out:
#      Register_ID    Country Validation       Began       Ended  \
# 10        4204.0  Indonesia       News  2014-11-14  2014-11-16
# 41        4173.0  Indonesia       News  2014-08-11  2014-08-19
# 93        4121.0  Indonesia       News  2014-01-08  2014-02-07
# 102       4112.0  Indonesia       News  2013-12-29  2014-01-04
# 118       4096.0  Indonesia       News  2013-10-07  2013-10-14
#
#      Duration in Days  Dead  Displaced       Main cause  Severity  \
# 10                3.0   0.0     2400.0       Heavy Rain       1.0
# 41                9.0   2.0      600.0  Torrential Rain       1.0
# 93               31.0  23.0    20000.0       Heavy Rain       1.5
# 102               7.0   0.0     4500.0       Heavy Rain       1.0
# 118               8.0   0.0    16000.0  Torrential Rain       1.5
#
#      Affected sq km  Magnitude  Longitude of Centroid X  \
# 10          57443.0       5.24                   100.75
# 41          65177.0       5.77                   107.83
# ...
